# %%
import pandas as pd
import numpy as np 
import datetime

# %%
data = pd.read_csv('888.csv', sep=';', decimal=',')
data.dropna(axis='columns', how='all', inplace=True)
data.head()
# Out:
# C:\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: DtypeWarning: Columns (7,13,19,31,37,43,49,55,73,79,85,91,97,115,121,127,133,139,157,163,169,175,181,199,205,211,217,223,241,247,253,259,265,283,289,295,301,307) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                    01 Tickers   ticker  10 декабря 2020; Open  \
# 0  Anheuser-Busch InBev SA/NV   ABI.BR              58.520000
# 1             AB Science S.A.    AB.PA              10.600000
# 2            ABC arbitrage SA  ABCA.PA               7.300000
# 3                     Abéo SA  ABEO.PA               9.400000
# 4      ABIVAX Société Anonyme  ABVX.PA              22.700001
#
#    10 декабря 2020; DayHigh  10 декабря 2020; DayLow  10 декабря 2020; Volume  \
# 0                 59.509998                58.299999                1646169.0
# 1                 10.940000                10.500000                 165124.0
# 2                  7.360000                 7.250000                  28455.0
# 3                 10.150000                 9.140000                  61275.0
# 4                 23.450001                22.250000                  22197.0
#
#    10 декабря 2020; Price 10 декабря 2020; Date  11 декабря 2020; Open  \
# 0               58.380001   10.12.2020 00:00:00              58.259998
# 1               10.700000   10.12.2020 00:00:00              10.600000
# 2                7.260000   10.12.2020 00:00:00               7.330000
# 3                9.300000   10.12.2020 00:00:00               9.440000
# 4               22.400000   10.12.2020 00:00:00              22.500000
#
#    11 декабря 2020; DayHigh  ...  28 января 2021; DayLow  \
# 0                 58.790001  ...               51.900002
# 1                 10.620000  ...               15.720000
# 2                  7.330000  ...                7.290000
# 3                  9.440000  ...               10.000000
# 4                 22.650000  ...               30.350000
#
#    28 января 2021; Volume  28 января 2021; Price 28 января 2021; Date  \
# 0               1798320.0              53.660000  28.01.2021 00:00:00
# 1                236883.0              16.480000  28.01.2021 00:00:00
# 2                 27051.0               7.390000  28.01.2021 00:00:00
# 3                  6969.0              10.350000  28.01.2021 00:00:00
# 4                 46417.0              31.950001  28.01.2021 00:00:00
#
#    29 января 2021; Open  29 января 2021; DayHigh  29 января 2021; DayLow  \
# 0             52.439999                53.049999                   51.98
# 1             16.160000                16.620001                   15.94
# 2              7.440000                 7.440000                    7.36
# 3             10.350000                10.350000                   10.10
# 4             31.700001                32.200001                   30.75
#
#    29 января 2021; Volume  29 января 2021; Price 29 января 2021; Date
# 0               2535830.0                  51.98  29.01.2021 00:00:00
# 1                153071.0                  16.24  29.01.2021 00:00:00
# 2                 35074.0                   7.40  29.01.2021 00:00:00
# 3                  1369.0                  10.10  29.01.2021 00:00:00
# 4                 27625.0                  31.10  29.01.2021 00:00:00
#
# [5 rows x 230 columns]

# %%
columns = data.columns

new_columns = []
new_columns.append(columns[0])
new_columns.append(columns[1])

for i in range(2, len(columns)):
    a, b = columns[i].split(';')
    date = a.split(' ')
    if date[1] == 'января':
        date[1] = 1
    elif date[1] == 'февраля':
        date[1] = 2
    elif date[1] == 'марта':
        date[1] = 3
    elif date[1] == 'апреля':
        date[1] = 4
    elif date[1] == 'мая':
        date[1] = 5
    elif date[1] == 'июня':
        date[1] = 6
    elif date[1] == 'июля':
        date[1] = 7
    elif date[1] == 'августа':
        date[1] = 8
    elif date[1] == 'сентября':
        date[1] = 9
    elif date[1] == 'октября':
        date[1] = 10
    elif date[1] == 'ноября':
        date[1] = 11
    elif date[1] == 'декабря':
        date[1] = 12
    else:
        break
    date = [int(x) for x in date]
    a = datetime.date(date[2], date[1], date[0])
    new_columns.append(a.strftime("%d-%m-%Y") + b)

data =data.rename(columns=dict(zip(columns, new_columns)))

# %%
data.head(3)
# Out:
#                    01 Tickers   ticker  10-12-2020 Open  10-12-2020 DayHigh  \
# 0  Anheuser-Busch InBev SA/NV   ABI.BR            58.52           59.509998
# 1             AB Science S.A.    AB.PA            10.60           10.940000
# 2            ABC arbitrage SA  ABCA.PA             7.30            7.360000
#
#    10-12-2020 DayLow  10-12-2020 Volume  10-12-2020 Price  \
# 0          58.299999          1646169.0         58.380001
# 1          10.500000           165124.0         10.700000
# 2           7.250000            28455.0          7.260000
#
#        10-12-2020 Date  11-12-2020 Open  11-12-2020 DayHigh  ...  \
# 0  10.12.2020 00:00:00        58.259998           58.790001  ...
# 1  10.12.2020 00:00:00        10.600000           10.620000  ...
# 2  10.12.2020 00:00:00         7.330000            7.330000  ...
#
#    28-01-2021 DayLow  28-01-2021 Volume  28-01-2021 Price  \
# 0          51.900002          1798320.0             53.66
# 1          15.720000           236883.0             16.48
# 2           7.290000            27051.0              7.39
#
#        28-01-2021 Date  29-01-2021 Open  29-01-2021 DayHigh  \
# 0  28.01.2021 00:00:00        52.439999           53.049999
# 1  28.01.2021 00:00:00        16.160000           16.620001
# 2  28.01.2021 00:00:00         7.440000            7.440000
#
#    29-01-2021 DayLow  29-01-2021 Volume  29-01-2021 Price      29-01-2021 Date
# 0              51.98          2535830.0             51.98  29.01.2021 00:00:00
# 1              15.94           153071.0             16.24  29.01.2021 00:00:00
# 2               7.36            35074.0              7.40  29.01.2021 00:00:00
#
# [3 rows x 230 columns]

# %% [raw]
# # inx = a.index
# dates = []
# data_Open = []
# data_DayHigh = []
# data_DayLow = []
# data_Volume = []
# data_Close = []
#
# for i in range(2, len(a)):
#
#     if 'Open' in inx[i]:
#         date, _ = inx[i].split(' ')
#         dates.append(date)
#         data_Open.append(a[i])
#
#     elif 'DayHigh' in inx[i]:
# #         date, _ = inx[i].split(' ')
#         data_DayHigh.append(a[i])
#
#     elif 'DayLow' in inx[i]:
# #         date, _ = inx[i].split(' ')
#         data_DayLow.append(a[i])
#
#
#     elif 'Volume' in inx[i]:
# #         date, _ = inx[i].split(' ')
#         data_Volume.append(a[i])
#
#
#     elif 'Price' in inx[i]:
# #         date, _ = inx[i].split(' ')
#         data_Close.append(a[i])
#
#
# data_of_company = pd.DataFrame({'data_Open' : data_Open, 'data_DayHigh': data_DayHigh, \
#               'data_DayLow': data_DayLow, 'data_Volume': data_Volume,\
#               'data_Close': data_Close}, index=dates)

# %%
def get_dataset_of_company(Tickers, ticker, data):
    
    data_index = data[(data['01 Tickers'] == Tickers)& (data['ticker'] == ticker )].index
    a = data.loc[data_index[0]]
    inx = a.index
    dates = []
    data_Open = []
    data_DayHigh = []
    data_DayLow = []
    data_Volume = []
    data_Close = []
    for i in range(2, len(a)):
        if 'Open' in inx[i]:
            date, _ = inx[i].split(' ')
            dates.append(date)
            data_Open.append(a[i])
        elif 'DayHigh' in inx[i]:
            data_DayHigh.append(a[i])
        elif 'DayLow' in inx[i]:
            data_DayLow.append(a[i])
        elif 'Volume' in inx[i]:
            data_Volume.append(a[i])
        elif 'Price' in inx[i]:
            data_Close.append(a[i])
    data_of_company = pd.DataFrame({'Open' : data_Open, 'DayHigh': data_DayHigh, \
              'DayLow': data_DayLow, 'Volume': data_Volume,\
              'Close': data_Close}, index=dates)
    return Tickers, ticker, data_of_company

def get_dataset_of_company_by_id(company_id, data):
    a = data.loc[company_id]
    inx = a.index
    dates = []
    data_Open = []
    data_DayHigh = []
    data_DayLow = []
    data_Volume = []
    data_Close = []
    for i in range(2, len(a)):
        if 'Open' in inx[i]:
            date, _ = inx[i].split(' ')
            dates.append(date)
            data_Open.append(a[i])
        elif 'DayHigh' in inx[i]:
            data_DayHigh.append(a[i])
        elif 'DayLow' in inx[i]:
            data_DayLow.append(a[i])
        elif 'Volume' in inx[i]:
            data_Volume.append(a[i])
        elif 'Price' in inx[i]:
            data_Close.append(a[i])
    data_of_company = pd.DataFrame({'Open' : data_Open, 'DayHigh': data_DayHigh, \
              'DayLow': data_DayLow, 'Volume': data_Volume,\
              'Close': data_Close}, index=dates)
    return a['01 Tickers'], a['ticker'], data_of_company

# %% [markdown]
# b = get_dataset_of_company('Anheuser-Busch InBev SA/NV', 'ABI.BR', data)

# %% [markdown]
# tickers, ticker, d = get_dataset_of_company_by_id(1, data)

# %% [markdown]
# tickers, ticker

# %% [markdown]
# d

# %%
import talib

# %%
def calculate_parametres(dataset, rsi=False, stoch=False, stochrsi=False, macd=False, adx=False, willr=False):
    if rsi:
        rsi_14 = talib.RSI(dataset['Close'],  timeperiod=14)
        dataset['RSI_14'] = rsi_14
        
    if stoch:
        slowk, fastd = talib.STOCH(dataset['DayHigh'], dataset['DayLow'], dataset['Close'], fastk_period=3,\
                                   slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)
        dataset['STOCH_slowk'] = slowk
        dataset['STOCH_fastd'] = fastd
        
    if stochrsi:
        fastk, fastd = talib.STOCHRSI(dataset['Close'],  timeperiod=14, fastk_period=5, fastd_period=3, fastd_matype=0)
        dataset['STOCHRSI_fastk'] = fastk
        dataset['STOCHRSI_fastd'] = fastd
        
    if macd:
        macd, macdsignal, macdhist = talib.MACD(dataset['Close'], fastperiod=12, slowperiod=26, signalperiod=9)
        dataset['MACD'] = macd
        dataset['MACD_signal'] = macdsignal
    
    if adx:
        real = talib.ADX(dataset['DayHigh'], dataset['DayLow'], dataset['Close'], timeperiod=14)
        dataset['ADX'] = real
        
    if willr:
        real = talib.WILLR(dataset['DayHigh'], dataset['DayLow'], dataset['Close'], timeperiod=14)
        dataset['WILLIAMS'] = real

# %%
a, b, d = get_dataset_of_company_by_id(0, data)

# %%
d
# Out:
#                  Open    DayHigh     DayLow     Volume      Close
# 10-12-2020  58.520000  59.509998  58.299999  1646169.0  58.380001
# 11-12-2020  58.259998  58.790001  56.849998  1627225.0  57.209999
# 12-12-2020        NaN        NaN        NaN        NaN        NaN
# 05-01-2021    13.749722    25.090299             NaN             NaN
# 06-01-2021    44.495551    26.506131             NaN             NaN
# 07-01-2021    62.685429    40.310234             NaN             NaN
# 08-01-2021    65.967595    57.716192             NaN             NaN
# 11-01-2021    38.190753    55.614592        0.000000    4.139262e+01
# 12-01-2021    21.209835    41.789394        0.000000    1.488952e+01
# 13-01-2021    21.224400    26.874996        0.000000    0.000000e+00
# 14-01-2021    36.100491    26.178242       49.471478    1.649049e+01
# 15-01-2021    41.300572    32.875154       63.494109    3.765520e+01
# 18-01-2021    50.476708    42.625924      100.000000    7.098853e+01
# 19-01-2021    41.975023    44.584101        8.584778    5.735963e+01
# 20-01-2021    34.795564    42.415765        0.000000    3.619493e+01
# 21-01-2021    15.497293    30.755960        0.000000    2.861593e+00
# 22-01-2021    14.455786    21.582881        0.000000    9.473903e-15
# 25-01-2021    10.851966    13.601682        0.000000    9.473903e-15
# 26-01-2021    17.015467    14.107740        0.000000    9.473903e-15
# 27-01-2021    18.288067    15.385167        0.000000    9.473903e-15
# 28-01-2021    46.943673    27.415736      100.000000    3.333333e+01
# 29-01-2021    42.198578    35.810106       21.234207    4.041140e+01
#
#                 MACD  MACD_signal        ADX    WILLIAMS
# 10-12-2020       NaN          NaN        NaN         NaN
# 11-12-2020       NaN          NaN        NaN         NaN
# 14-12-2020       NaN          NaN        NaN         NaN
# 15-12-2020       NaN          NaN        NaN         NaN
# 16-12-2020       NaN          NaN        NaN         NaN
# 17-12-2020       NaN          NaN        NaN         NaN
# 18-12-2020       NaN          NaN        NaN         NaN
# 21-12-2020       NaN          NaN        NaN         NaN
# 22-12-2020       NaN          NaN        NaN         NaN
# 23-12-2020       NaN          NaN        NaN         NaN
# 24-12-2020       NaN          NaN        NaN         NaN
# 28-12-2020       NaN          NaN        NaN         NaN
# 29-12-2020       NaN          NaN        NaN         NaN
# 30-12-2020       NaN          NaN        NaN  -31.012608
# 31-12-2020       NaN          NaN        NaN  -45.762787
# 04-01-2021       NaN          NaN        NaN  -40.920150
# 05-01-2021       NaN          NaN        NaN  -41.646517
# 06-01-2021       NaN          NaN        NaN   -4.076716
# 07-01-2021       NaN          NaN        NaN  -12.949571
# 08-01-2021       NaN          NaN        NaN  -25.899239
# 11-01-2021       NaN          NaN        NaN  -55.875265
# 12-01-2021       NaN          NaN        NaN  -79.934322
# 13-01-2021       NaN          NaN        NaN  -80.921100
# 14-01-2021       NaN          NaN        NaN  -65.131643
# 15-01-2021       NaN          NaN        NaN  -72.368394
# 18-01-2021       NaN          NaN        NaN  -61.184172
# 19-01-2021       NaN          NaN        NaN  -85.197485
# 20-01-2021       NaN          NaN  13.948060  -88.815778
# 21-01-2021       NaN          NaN  14.646473 -100.000000
# 22-01-2021       NaN          NaN  16.135093  -86.307054
# 25-01-2021       NaN          NaN  18.192446  -95.371917
# 26-01-2021       NaN          NaN  20.229772  -92.134864
# 27-01-2021       NaN          NaN  22.425838  -87.383166
# 28-01-2021 -1.206789    -0.761814  24.501757  -70.568590
# 29-01-2021 -1.346619    -0.878775  26.429396  -98.662241

# %%
d.shape
# Out:
# (35, 14)
